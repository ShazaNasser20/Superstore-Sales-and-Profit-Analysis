# %% [markdown]
# <div style="background-color:#1B4F72; border-radius:10px; padding:28px 30px; margin-bottom:10px;">
# <h1 style="color:#FFFFFF; margin:0;">📊 Superstore Sales &amp; Profit Analysis</h1>
# <p style="color:#D6EAF8; margin:10px 0 0 0; font-size:15px;">An end-to-end Exploratory Data Analysis of the Sample Superstore dataset, uncovering the sales and profitability drivers behind the business.</p>
# </div>
#
# <p style="color:#5D6D7E; font-size:13px; margin-top:8px;">Author: Data Analyst Portfolio Project &nbsp;|&nbsp; Tools: Python, Pandas, Matplotlib, Seaborn &nbsp;|&nbsp; Dataset: Sample Superstore</p>

# %% [markdown]
# <div style="background-color:#F8F9F9;
# padding:18px;
# border-radius:8px;
# border-left:5px solid #2E86C1;">
#
# <h3>📑 Table of Contents</h3>
#
# 1. Business Problem
# 2. Objectives
# 3. Tools & Technologies
# 4. Data Understanding
# 5. Data Cleaning
# 6. Exploratory Data Analysis
# 7. Overall Business Insights
# 8. Final Recommendations
# 9. Conclusion
#
# </div>

# %% [markdown]
# <div style="background-color:#EBF5FB;
# padding:18px;
# border-radius:10px;
# border-left:6px solid #3498DB;">
#
# <b>📌 Project Type:</b> Exploratory Data Analysis (EDA)<br><br>
#
# <b>🏢 Domain:</b> Retail Analytics<br><br>
#
# <b>📊 Dataset:</b> Superstore Sales Dataset
#
# </div>

# %% [markdown]
# <div style="background-color:#EAF4FB; border-left:6px solid #2E86C1; border-radius:8px; padding:14px 22px; margin:35px 0 18px 0;">
# <h1 style="color:#1B4F72; margin:0; font-family:Segoe UI, Arial, sans-serif;">📌 Business Problem</h1>
# </div>

# %% [markdown]
# Retail businesses generate large volumes of transactional data, but without structured analysis this data rarely translates into actionable decisions. Management needs a clear, evidence-based view of how sales and profit are distributed across products, regions, customer segments, and shipping methods in order to identify what is working well and where performance is being held back.
#
# This project analyzes the Superstore dataset to uncover the key drivers of sales and profitability and to translate those findings into concrete, data-backed business recommendations.

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:8px 18px; margin:22px 0 10px 0;">
# <h2 style="color:#21618C; margin:0; font-family:Segoe UI, Arial, sans-serif;">🎯 Objectives</h2>
# </div>

# %% [markdown]
# - Evaluate overall sales and profit performance across the business.
# - Identify the most and least profitable product categories and sub-categories.
# - Compare sales and profitability across regions, customer segments, and shipping modes.
# - Examine the relationship between discounting and profitability.
# - Translate the findings into practical, actionable business recommendations.

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:8px 18px; margin:22px 0 10px 0;">
# <h2 style="color:#21618C; margin:0; font-family:Segoe UI, Arial, sans-serif;">🛠 Tools &amp; Technologies</h2>
# </div>

# %% [markdown]
# | Tool | Purpose |
# |---|---|
# | **Python** | Core programming language for the analysis |
# | **Pandas** | Data loading, cleaning, and aggregation |
# | **Matplotlib / Seaborn** | Data visualization |
# | **Jupyter Notebook** | Interactive analysis and reporting |

# %% [markdown]
# ## 📁 Dataset Source
#
# Dataset: Sample Superstore
#
# Source: Kaggle

# %% [markdown]
# <div style="background-color:#EAF4FB; border-left:6px solid #2E86C1; border-radius:8px; padding:14px 22px; margin:35px 0 18px 0;">
# <h1 style="color:#1B4F72; margin:0; font-family:Segoe UI, Arial, sans-serif;">📂 Data Understanding</h1>
# </div>

# %% [markdown]
# This section loads the dataset and performs an initial inspection of its structure, data types, and summary statistics before any cleaning is applied.

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">⚙️ Setup &amp; Imports</p>

# %%
# Core libraries for data handling and visualization
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Global visualization settings — ensures a consistent, professional look
# across every chart in this notebook
sns.set_theme(style="whitegrid")
ACCENT_COLOR = "#2E86C1"       # single accent color used across all charts
plt.rcParams["figure.dpi"] = 100
plt.rcParams["axes.titleweight"] = "bold"


def finalize_plot(title, xlabel, ylabel, rotate=0):
    """Apply consistent titles, labels, spacing, and grid styling to the
    current matplotlib figure, then render it."""
    plt.title(title, fontsize=13, pad=12)
    plt.xlabel(xlabel, fontsize=11)
    plt.ylabel(ylabel, fontsize=11)
    if rotate:
        plt.xticks(rotation=rotate, ha="right")
    plt.grid(axis="y", alpha=0.3)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📥 Load Dataset</p>

# %%
df = pd.read_csv("SampleSuperstore.csv", encoding="latin1")
df = df.rename(columns={"Sub_Category": "Sub-Category"})
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🔎 Structure &amp; Data Types</p>

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# <hr style="border:none; border-top:1px solid #D5DBDB; margin:30px 0;">

# %% [markdown]
# <div style="background-color:#EAF4FB; border-left:6px solid #2E86C1; border-radius:8px; padding:14px 22px; margin:35px 0 18px 0;">
# <h1 style="color:#1B4F72; margin:0; font-family:Segoe UI, Arial, sans-serif;">🧹 Data Cleaning</h1>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🕳️ Missing Values</p>

# %%
# Check for missing values across all columns
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧾 Duplicate Records</p>

# %% [markdown]
# The dataset contains duplicate rows. After verifying that these rows are exact duplicates, they were removed to improve data quality.

# %%
# Count duplicated rows
df.duplicated().sum()
# Out:
# np.int64(17)

# %%
# Inspect the duplicated rows before removing them
duplicates = df[df.duplicated()]
duplicates
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %%
# Remove duplicate rows
df = df.drop_duplicates()

# Confirm the dataset shape after removing duplicates
df.shape
# Out:
# (9977, 13)

# %%
# Verify that no duplicate rows remain
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(5, random_state=42)
# Out:
#            Ship Mode    Segment        Country           City           State  \
# 5830  Standard Class   Consumer  United States       Richmond         Indiana
# 5176     First Class   Consumer  United States  San Francisco      California
# 6047  Standard Class  Corporate  United States          Miami         Florida
# 107   Standard Class   Consumer  United States      Charlotte  North Carolina
# 3424  Standard Class   Consumer  United States    Los Angeles      California
#
#       Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 5830        47374  Central        Furniture       Chairs   29.980         1
# 5176        94109     West  Office Supplies      Binders   53.248         2
# 6047        33142    South  Office Supplies      Binders   16.146         9
# 107         28205    South       Technology       Phones   27.992         1
# 3424        90004     West       Technology     Machines  558.400         2
#
#       Discount   Profit
# ...

# %% [markdown]
# <div style="background-color:#FEF9E7; border:1px dashed #D68910; border-radius:6px; padding:10px 16px; margin:12px 0; font-style:italic; color:#7D6608;">
# 📝 No missing values were found in the dataset. 17 duplicate rows were identified and removed, leaving a clean dataset of 9,977 rows and 13 columns.
# </div>

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:8px 18px; margin:22px 0 10px 0;">
# <h2 style="color:#21618C; margin:0; font-family:Segoe UI, Arial, sans-serif;">📋 Dataset Overview</h2>
# </div>

# %%
# Professional summary of the cleaned dataset
overview = pd.DataFrame({
    "Metric": [
        "Number of records",
        "Number of features",
        "Missing values",
        "Duplicate rows removed",
        "Categorical columns",
        "Numerical columns",
    ],
    "Value": [
        df.shape[0],
        df.shape[1],
        int(df.isnull().sum().sum()),
        17,
        df.select_dtypes(include="object").shape[1],
        df.select_dtypes(exclude="object").shape[1],
    ],
})
overview
# Out:
#                    Metric  Value
# 0       Number of records   9977
# 1      Number of features     13
# 2          Missing values      0
# 3  Duplicate rows removed     17
# 4     Categorical columns      8
# 5       Numerical columns      5

# %% [markdown]
# <hr style="border:none; border-top:1px solid #D5DBDB; margin:30px 0;">

# %% [markdown]
# <div style="background-color:#EAF4FB; border-left:6px solid #2E86C1; border-radius:8px; padding:14px 22px; margin:35px 0 18px 0;">
# <h1 style="color:#1B4F72; margin:0; font-family:Segoe UI, Arial, sans-serif;">📈 Exploratory Data Analysis</h1>
# </div>

# %% [markdown]
# Each question below follows the same structure: the underlying analysis, a supporting visualization, an observation of what the data shows, the business insight derived from it, and a corresponding recommendation.

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 1</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which product category generates the highest total sales?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
category_sales = (
    df.groupby("Category")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

category_sales
# Out:
# Category
# Technology         836154.0330
# Furniture          741306.3133
# Office Supplies    718735.2440
# Name: Sales, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(8, 5))

sns.barplot(x=category_sales.index, y=category_sales.values, color=ACCENT_COLOR)

finalize_plot("Total Sales by Category", "Category", "Total Sales")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Technology generated the highest total sales, followed by Furniture and Office Supplies.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Technology is the top-performing category by revenue, reflecting strong and consistent customer demand. Sustaining sufficient inventory levels and reinforcing marketing efforts around this category will help the business capitalize on its momentum.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Increase investment in the Technology category by ensuring product availability and launching targeted marketing campaigns to further boost sales.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 2</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which product category generates the highest total profit?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
category_profit = (
    df.groupby("Category")["Profit"]
    .sum()
    .sort_values(ascending=False)
)

category_profit
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122364.6608
# Furniture           18421.8137
# Name: Profit, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(8, 5))

sns.barplot(x=category_profit.index, y=category_profit.values, color=ACCENT_COLOR)

finalize_plot("Total Profit by Category", "Category", "Total Profit")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Technology recorded the highest total profit, followed by Office Supplies, while Furniture generated the lowest total profit.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Although Furniture ranks second in total sales, it delivers the lowest profit of all categories. This gap points to elevated costs or excessive discounting eroding its margins, making it the least profitable category despite healthy revenue.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Review the pricing strategy and discount policy for Furniture products to improve profitability while maintaining sales performance.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 3</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which region generates the highest total sales?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
region_sales = (
    df.groupby("Region")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

region_sales
# Out:
# Region
# West       725255.6365
# East       678435.1960
# Central    500782.8528
# South      391721.9050
# Name: Sales, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(8, 5))

sns.barplot(x=region_sales.index, y=region_sales.values, color=ACCENT_COLOR)

finalize_plot("Total Sales by Region", "Region", "Total Sales")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The West region generates the highest total sales, followed by the East, Central, and South regions.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The West region is the company's strongest sales performer, signaling high customer demand in that market. Understanding what drives this performance can help identify strategies worth replicating in lower-performing regions.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Maintain strong inventory and marketing efforts in the West region, while developing targeted strategies to improve sales performance in the South and Central regions.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 4</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which region generates the highest total profit?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
region_profit = (
    df.groupby("Region")["Profit"]
    .sum()
    .sort_values(ascending=False)
)

region_profit
# Out:
# Region
# West       108329.8079
# East        91506.3092
# South       46749.4303
# Central     39655.8752
# Name: Profit, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(8, 5))

sns.barplot(x=region_profit.index, y=region_profit.values, color=ACCENT_COLOR)

finalize_plot("Total Profit by Region", "Region", "Total Profit")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The West region generated the highest total profit, followed by the East, South, and Central regions, with the Central region recording the lowest profit.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The West region leads in both total sales and total profit, underscoring its strength as the company's most valuable market. By contrast, the Central region's low profitability suggests underlying issues such as higher operational costs, a weaker product mix, or excessive discounting that merit closer investigation.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Continue investing in the successful strategies driving performance in the West region, while conducting a detailed review of pricing, discounting, and operational efficiency in the Central region.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 5</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which sub-category generates the highest total sales?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
subcategory_sales = (
    df.groupby("Sub-Category")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

subcategory_sales
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         327777.7610
# Storage        223843.6080
# Tables         206965.5320
# Binders        203409.1690
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91683.0240
# Paper           78224.1420
# Supplies        46673.5380
# Art             27107.0320
# Envelopes       16476.4020
# Labels          12444.9120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x=subcategory_sales.index, y=subcategory_sales.values, color=ACCENT_COLOR)

finalize_plot("Total Sales by Sub-Category", "Sub-Category", "Total Sales", rotate=45)

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Phones generated the highest total sales, closely followed by Chairs, while Fasteners recorded the lowest total sales among all sub-categories.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Phones stand out as the strongest sales driver in the portfolio, reflecting sustained customer demand. Fasteners, on the other hand, contribute minimally to revenue, indicating either weak demand or a narrow product offering within that line.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Maintain sufficient inventory and marketing support for Phones to sustain demand, while evaluating whether low-performing sub-categories such as Fasteners should be improved, repositioned, or discontinued.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 6</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which sub-category generates the highest total profit?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
subcategory_profit = (
    df.groupby("Sub-Category")["Profit"]
    .sum()
    .sort_values(ascending=False)
)

subcategory_profit
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          33944.2395
# Binders        30228.0003
# Chairs         26567.1278
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13052.7230
# Envelopes       6964.1767
# Art             6524.6118
# Labels          5526.3820
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x=subcategory_profit.index, y=subcategory_profit.values, color=ACCENT_COLOR)

finalize_plot("Total Profit by Sub-Category", "Sub-Category", "Total Profit", rotate=45)

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Copiers generated the highest total profit, followed by Phones and Accessories, while Tables, Bookcases, and Supplies recorded negative profit overall.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">While several sub-categories deliver strong profitability, others are operating at a loss. The negative margins in Tables, Bookcases, and Supplies point to potential issues in pricing, discounting, or cost structure that warrant further investigation.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Review the pricing strategy, discount policy, and cost structure behind Tables, Bookcases, and Supplies to restore profitability, while continuing to support high-margin sub-categories such as Copiers and Phones through effective inventory and marketing planning.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 7</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Does discount affect profit?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
df[["Discount", "Profit"]].describe()
# Out:
#           Discount      Profit
# count  9977.000000  9977.00000
# mean      0.156278    28.69013
# std       0.206455   234.45784
# min       0.000000 -6599.97800
# 25%       0.000000     1.72620
# 50%       0.200000     8.67100
# 75%       0.200000    29.37200
# max       0.800000  8399.97600

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x="Discount", y="Profit", color=ACCENT_COLOR, alpha=0.6)

finalize_plot("Relationship Between Discount and Profit", "Discount", "Profit")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The scatter plot shows a clear negative relationship between discount and profit. As the discount rate increases, profit tends to decrease, with many transactions turning negative at higher discount levels — particularly around 50%, 70%, and 80%.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Higher discounts are associated with a significant erosion of profitability. While discounting can help drive sales volume, excessive discount levels are linked to substantial financial losses, suggesting the current discount strategy should be reassessed to balance customer demand with margin protection.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Review the current discount policy and avoid offering excessive discounts unless justified by clear strategic objectives. Further analysis should identify the specific products and regions most affected by high discount rates.</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📐 Correlation Analysis</p>

# %% [markdown]
# The Pearson correlation coefficient measures the strength and direction of the linear relationship between Discount and Profit.

# %%
correlation = df["Discount"].corr(df["Profit"])
print(f"Correlation between Discount and Profit: {correlation:.2f}")
# Out:
# Correlation between Discount and Profit: -0.22

# %% [markdown]
# <div style="background-color:#FEF9E7; border:1px dashed #D68910; border-radius:6px; padding:10px 16px; margin:12px 0; font-style:italic; color:#7D6608;">
# 📝 The correlation coefficient is **-0.22**, indicating a weak negative relationship between discount and profit — as discounts increase, profit tends to decrease, although the relationship is not strong.
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Additional Visualization</p>

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=df, x="Discount", y="Profit", color=ACCENT_COLOR)

finalize_plot("Profit Distribution by Discount Level", "Discount", "Profit")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The box plot offers a clearer view of how the profit distribution shifts across discount levels. Higher discount rates are associated with lower median profit and a greater concentration of negative-profit transactions.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 8</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which customer segment generates the highest total sales?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
segment_sales = (
    df.groupby("Segment")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

segment_sales
# Out:
# Segment
# Consumer       1.160833e+06
# Corporate      7.060701e+05
# Home Office    4.292927e+05
# Name: Sales, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(8, 5))

sns.barplot(x=segment_sales.index, y=segment_sales.values, color=ACCENT_COLOR)

finalize_plot("Total Sales by Customer Segment", "Customer Segment", "Total Sales")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The Consumer segment generated the highest total sales, followed by Corporate, while Home Office recorded the lowest total sales.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The Consumer segment is the company's primary source of revenue, reflecting strong demand from individual buyers. As the largest market opportunity, it should remain a central focus of the growth strategy.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Continue investing in marketing campaigns and customer engagement strategies targeting the Consumer segment, while identifying opportunities to grow sales within the Corporate and Home Office segments.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 9</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which customer segment generates the highest total profit?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
segment_profit = (
    df.groupby("Segment")["Profit"]
    .sum()
    .sort_values(ascending=False)
)

segment_profit
# Out:
# Segment
# Consumer       134007.4413
# Corporate       91954.9798
# Home Office     60279.0015
# Name: Profit, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(8, 5))

sns.barplot(x=segment_profit.index, y=segment_profit.values, color=ACCENT_COLOR)

finalize_plot("Total Profit by Customer Segment", "Customer Segment", "Total Profit")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The Consumer segment generated the highest total profit, followed by Corporate, while Home Office generated the lowest total profit.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">The Consumer segment leads in both sales and profit, making it the company's most valuable customer group. Sustaining satisfaction and loyalty within this segment is essential to long-term business performance.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Prioritize customer retention programs and personalized marketing for the Consumer segment, while exploring strategies to improve profitability within the Corporate and Home Office segments.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 10</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which shipping mode generates the highest total profit?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
shipping_profit = (
    df.groupby("Ship Mode")["Profit"]
    .sum()
    .sort_values(ascending=False)
)

shipping_profit
# Out:
# Ship Mode
# Standard Class    163969.2280
# Second Class       57446.6516
# First Class        48953.6561
# Same Day           15871.8869
# Name: Profit, dtype: float64

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(9, 5))

sns.barplot(x=shipping_profit.index, y=shipping_profit.values, color=ACCENT_COLOR)

finalize_plot("Total Profit by Shipping Mode", "Shipping Mode", "Total Profit")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Standard Class generated the highest total profit, followed by Second Class, First Class, and Same Day shipping.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Standard Class is the most profitable shipping method, suggesting it strikes an effective balance between operational cost and customer demand. Faster shipping options contribute comparatively less to overall profit, likely due to higher fulfillment costs.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Continue promoting Standard Class as the default shipping option, while evaluating the pricing and operational efficiency of premium shipping methods to improve their profitability.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFFFFF; border:1px solid #D6E9F5; border-left:5px solid #2E86C1; border-radius:8px; padding:12px 18px; margin:28px 0 8px 0;">
# <h3 style="color:#154360; margin:0;">❓ Question 11</h3>
# <p style="margin:6px 0 0 0; color:#212f3c; font-size:15px;">Which sub-categories have high sales but low or negative profit?</p>
# </div>

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">🧮 Analysis</p>

# %%
subcategory_analysis = (
    df.groupby("Sub-Category")[["Sales", "Profit"]]
    .sum()
    .sort_values(by="Sales", ascending=False)
)

subcategory_analysis
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        330007.0540  44515.7306
# Chairs        327777.7610  26567.1278
# Storage       223843.6080  21278.8264
# Tables        206965.5320 -17725.4811
# Binders       203409.1690  30228.0003
# Machines      189238.6310   3384.7569
# Accessories   167380.3180  41936.6357
# Copiers       149528.0300  55617.8249
# Bookcases     114879.9963  -3472.5560
# Appliances    107532.1610  18138.0054
# Furnishings    91683.0240  13052.7230
# Paper          78224.1420  33944.2395
# Supplies       46673.5380  -1189.0995
# Art            27107.0320   6524.6118
# Envelopes      16476.4020   6964.1767
# Labels         12444.9120   5526.3820
# Fasteners       3024.2800    949.5182

# %% [markdown]
# <p style="color:#1B4F72; font-weight:600; margin:14px 0 4px 0;">📊 Visualization</p>

# %%
plt.figure(figsize=(12, 6))

sns.scatterplot(
    data=subcategory_analysis,
    x="Sales",
    y="Profit",
    s=120,
    color=ACCENT_COLOR,
)

for sub_category in subcategory_analysis.index:
    plt.text(
        subcategory_analysis.loc[sub_category, "Sales"],
        subcategory_analysis.loc[sub_category, "Profit"],
        sub_category,
        fontsize=9,
    )

finalize_plot("Sales vs. Profit by Sub-Category", "Total Sales", "Total Profit")

# %% [markdown]
# <div style="background-color:#F4F9FC; border-left:4px solid #5DADE2; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#5DADE2;">🔍 Observation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Several sub-categories generate high sales but relatively low or even negative profit. Tables, for example, generated over **206K** in sales but resulted in a loss of approximately **17.7K**. Bookcases achieved more than **114K** in sales but also recorded negative profit. Copiers, by contrast, generated lower sales than Phones yet achieved the highest total profit of any sub-category.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FEF9E7; border-left:4px solid #D68910; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#D68910;">💡 Business Insight</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">High sales do not necessarily translate into high profitability. Tables and Bookcases contribute meaningfully to revenue but ultimately reduce overall profitability due to financial losses, while Copiers demonstrate strong profitability despite comparatively modest sales — making them one of the company's most valuable product lines.</p>
# </div>

# %% [markdown]
# <div style="background-color:#EAFAF1; border-left:4px solid #28B463; border-radius:6px; padding:10px 16px; margin:10px 0;">
# <b style="color:#28B463;">✅ Recommendation</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">Investigate the pricing strategy, discount policy, and cost structure behind Tables and Bookcases to identify the causes of their losses, while continuing to support high-profit products such as Copiers and Phones through effective inventory planning and targeted marketing.</p>
# </div>

# %% [markdown]
# <hr style="border:none; border-top:1px solid #D5DBDB; margin:30px 0;">

# %% [markdown]
# <div style="background-color:#EAF4FB; border-left:6px solid #2E86C1; border-radius:8px; padding:14px 22px; margin:35px 0 18px 0;">
# <h1 style="color:#1B4F72; margin:0; font-family:Segoe UI, Arial, sans-serif;">📋 Overall Business Insights</h1>
# </div>

# %% [markdown]
# 1. Technology is the leading product category in both sales and profit.
# 2. Furniture achieves high sales but delivers relatively low profit, pointing to pricing or cost challenges.
# 3. The West region is the strongest performer in both sales and profitability.
# 4. Consumer is the company's most valuable customer segment, contributing the highest sales and profit.
# 5. Standard Class is the most profitable shipping mode.
# 6. Higher discounts are associated with lower profits, highlighting the need to review discount strategy.
# 7. High sales do not always translate into high profit — sub-categories such as Tables and Bookcases generate significant revenue while eroding overall profitability.

# %% [markdown]
# <div style="background-color:#EAF4FB; border-left:6px solid #2E86C1; border-radius:8px; padding:14px 22px; margin:35px 0 18px 0;">
# <h1 style="color:#1B4F72; margin:0; font-family:Segoe UI, Arial, sans-serif;">✅ Final Recommendations</h1>
# </div>

# %% [markdown]
# - Maintain investment in high-performing categories such as Technology.
# - Review pricing and discount strategies for low-profit products, particularly Tables and Bookcases.
# - Continue prioritizing the Consumer segment through retention programs and targeted marketing.
# - Reinforce the strategies driving success in the West region and evaluate their applicability to lower-performing regions.
# - Optimize discount policies to balance customer demand with profitability.
# - Prioritize high-margin products such as Copiers while addressing the losses in underperforming sub-categories.

# %% [markdown]
# <div style="background-color:#EAF4FB; border-left:6px solid #2E86C1; border-radius:8px; padding:14px 22px; margin:35px 0 18px 0;">
# <h1 style="color:#1B4F72; margin:0; font-family:Segoe UI, Arial, sans-serif;">🏁 Conclusion</h1>
# </div>

# %% [markdown]
# This analysis shows that overall sales volume is not always a reliable indicator of profitability. While Technology and the Consumer segment drive strong performance across both sales and profit, categories such as Furniture and sub-categories such as Tables and Bookcases generate substantial revenue while eroding margins — largely linked to the negative relationship between discounting and profit observed throughout the dataset. Regionally, the West stands out as the strongest market, while the Central region lags behind on profitability despite reasonable sales volume.
#
# Taken together, these findings suggest that the business's next stage of growth depends less on generating additional sales and more on protecting margins — through disciplined discounting, closer attention to underperforming product lines, and the deliberate replication of what is already working in the West region and the Consumer segment.
#
# <div style="background-color:#EAF4FB; border-radius:8px; padding:14px 20px; margin-top:16px;">
# <b style="color:#1B4F72;">📁 Project Summary:</b>
# <p style="margin:6px 0 0 0; color:#212f3c;">This notebook demonstrates an end-to-end EDA workflow — from data cleaning and validation to visualization, interpretation, and business recommendations — using the Superstore dataset as a case study in translating raw transactional data into actionable strategy.</p>
# </div>
